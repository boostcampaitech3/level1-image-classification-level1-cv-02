# %%
import os

import pandas as pd

DATA_PATH = '/opt/ml/input/cropped_v2/train/'
IMG_PATH = '/opt/ml/input/cropped_v2/train/images/'

# %%
df = pd.read_csv('/opt/ml/input/cropped_v2/train/train_outlier.csv')

# %%
img_path_list = []

# %%
for p in df['path'].values:
    try : img_list = sorted([im for im in os.listdir(IMG_PATH+p) if '._' not in im])
    except : pass
    for im in img_list:
        img_path_list.append(p+'/'+im)

# %%
len(img_path_list)
# Out:
# 18900

# %%
df_cls = pd.DataFrame( { 'img_path' : img_path_list} )

# %%
def path_finder(x):
    return x.split('/')[0]

# %%
def name_finder(x):
    return x.split('/')[-1]

# %%
def mask_classifier(x):
    mask = x.split('.')[0]
    
    if mask == 'incorrect_mask':
        return 'Incorrect'
    elif mask == 'normal':
        return 'Not Wear'
    else:
        return 'Wear'

# %%
df_cls['path'] = df_cls['img_path'].map(path_finder)
df_cls['name'] = df_cls['img_path'].map(name_finder)
df_cls['mask'] = df_cls['name'].map(mask_classifier)

# %%
df_cls = pd.merge(df, df_cls, on='path')

# %%
df_cls['target'] = 0


df_cls['target'] = ((df_cls['mask']=='Not Wear')*12 + 
                  (df_cls['mask']=='Incorrect')*6 +
                  (df_cls['gender']=='female')*3 + 
                  (df_cls['age']>=30)*1 + 
                  (df_cls['age']>=60)*1)

# %%
df_cls
# Out:
#            id  gender   race  age                    path  \
# 0      000001  female  Asian   45  000001_female_Asian_45
# 1      000001  female  Asian   45  000001_female_Asian_45
# 2      000001  female  Asian   45  000001_female_Asian_45
# 3      000001  female  Asian   45  000001_female_Asian_45
# 4      000001  female  Asian   45  000001_female_Asian_45
# ...       ...     ...    ...  ...                     ...
# 18895  006959    male  Asian   19    006959_male_Asian_19
# 18896  006959    male  Asian   19    006959_male_Asian_19
# 18897  006959    male  Asian   19    006959_male_Asian_19
# 18898  006959    male  Asian   19    006959_male_Asian_19
# 18899  006959    male  Asian   19    006959_male_Asian_19
#
#                                         img_path                name  \
# 0      000001_female_Asian_45/incorrect_mask.jpg  incorrect_mask.jpg
# 1               000001_female_Asian_45/mask1.jpg           mask1.jpg
# 2               000001_female_Asian_45/mask2.jpg           mask2.jpg
# 3               000001_female_Asian_45/mask3.jpg           mask3.jpg
# 4               000001_female_Asian_45/mask4.jpg           mask4.jpg
# ...                                          ...                 ...
# 18895             006959_male_Asian_19/mask2.jpg           mask2.jpg
# 18896             006959_male_Asian_19/mask3.jpg           mask3.jpg
# 18897             006959_male_Asian_19/mask4.jpg           mask4.jpg
# 18898             006959_male_Asian_19/mask5.jpg           mask5.jpg
# 18899            006959_male_Asian_19/normal.jpg          normal.jpg
#
#             mask  target
# 0      Incorrect      10
# 1           Wear       4
# 2           Wear       4
# 3           Wear       4
# 4           Wear       4
# ...          ...     ...
# 18895       Wear       0
# 18896       Wear       0
# 18897       Wear       0
# 18898       Wear       0
# 18899   Not Wear      12
#
# [18900 rows x 9 columns]

# %%
df_cls.to_csv(DATA_PATH+'train_classified.csv', index=False)

# %%
df_cls['target'] = 0
df_cls['target'] = ((df_cls['mask']=='Not Wear')*12 + 
                  (df_cls['mask']=='Incorrect')*6)
df_cls.to_csv(DATA_PATH+'train_classified_mask.csv', index=False)

# %%
df_cls['target'] = 0
df_cls['target'] = (df_cls['gender']=='female')*3
df_cls.to_csv(DATA_PATH+'train_classified_gender.csv', index=False)

# %%
df_cls['target'] = 0
df_cls['target'] = ((df_cls['age']>=30)*1 + 
                  (df_cls['age']>=60)*1)
df_cls.to_csv(DATA_PATH+'train_classified_age.csv', index=False)

# %%
df_cls
# Out:
#            id  gender   race  age                    path  \
# 0      000001  female  Asian   45  000001_female_Asian_45
# 1      000001  female  Asian   45  000001_female_Asian_45
# 2      000001  female  Asian   45  000001_female_Asian_45
# 3      000001  female  Asian   45  000001_female_Asian_45
# 4      000001  female  Asian   45  000001_female_Asian_45
# ...       ...     ...    ...  ...                     ...
# 18895  006959    male  Asian   19    006959_male_Asian_19
# 18896  006959    male  Asian   19    006959_male_Asian_19
# 18897  006959    male  Asian   19    006959_male_Asian_19
# 18898  006959    male  Asian   19    006959_male_Asian_19
# 18899  006959    male  Asian   19    006959_male_Asian_19
#
#                                         img_path                name  \
# 0      000001_female_Asian_45/incorrect_mask.jpg  incorrect_mask.jpg
# 1               000001_female_Asian_45/mask1.jpg           mask1.jpg
# 2               000001_female_Asian_45/mask2.jpg           mask2.jpg
# 3               000001_female_Asian_45/mask3.jpg           mask3.jpg
# 4               000001_female_Asian_45/mask4.jpg           mask4.jpg
# ...                                          ...                 ...
# 18895             006959_male_Asian_19/mask2.jpg           mask2.jpg
# 18896             006959_male_Asian_19/mask3.jpg           mask3.jpg
# 18897             006959_male_Asian_19/mask4.jpg           mask4.jpg
# 18898             006959_male_Asian_19/mask5.jpg           mask5.jpg
# 18899            006959_male_Asian_19/normal.jpg          normal.jpg
#
#             mask  target
# 0      Incorrect       1
# 1           Wear       1
# 2           Wear       1
# 3           Wear       1
# 4           Wear       1
# ...          ...     ...
# 18895       Wear       0
# 18896       Wear       0
# 18897       Wear       0
# 18898       Wear       0
# 18899   Not Wear       0
#
# [18900 rows x 9 columns]
